# %% [markdown]
# # 2024-11-15 HR Diagrams and Stellar Evolution

# %% [markdown]
# ## Some review: HR Diagrams
#
# In several recent lectures we worked on calibrating our photometry to remove atmospheric effects. When we tried making an HR diagram of our stars, though, we didn't get a nice clear pattern until we took into account the fact that different stars in a typical field are at a different distances. The plot below shows the calibrated color-magnitude daiagram for the field of M74 on the left, and one in which distance has been taken into account on the right.

# %% [markdown]
# ### Diagram for field of the galaxy M74

# %% [markdown]
# ![M74 HR diagram](media/m74-hr.png)

# %% [markdown]
# ## Main sequence lifetimes
#
# Go to [this interactive](http://jupyter.mnstate.edu:8866/voila/render/Interactives/HR_Diagram.ipynb) and answer these questions:
#
# 1. How can an open cluster be used to measure distance?
# 2. How does the HR diagram change as time goes on?

# %% [markdown]
# ## Open cluster M103
#
# An image of the cluster M103 is below. The blue circles mark the stars that are thought to be cluster members. The yellow circles are the stars included in our photometry. Note that those two do not always match up well.
#
# An open cluster is "litter" of stars which all formed at around the same time.
#
# ![M103 color image](media/M103-color.png)

# %% [markdown]
# ### M103 cluster members
#
# ![M103 image](media/M03-members-marked.png)

# %% [markdown]
# ### Color-magnitude diagram for M103
#
# The color-magnitude diagram for the stars that are likely in the cluster is below.
#
# ![M103 members HR diagram](media/m103-hr-diagram.png)

# %% [markdown]
# ### Globular cluster M92
#
# The globular cluster M92 is below.

# %% [markdown]
# ![M92 image](media/M92-colot.png)
