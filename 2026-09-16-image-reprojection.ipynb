# %% [markdown]
# # 2026-09-16 Next two weeks + color image next steps

# %% [markdown]
# ## This week and next

# %% [markdown]
# + Today: Align images for color picture + an unexpected thing
# + Friday: Combine images in each filter
# + Monday (Matt in England): Make a first draft of your color image
# + Wednesday (Matt in England): MEET IN THE PLANETARIUM IN BRIDGES -- celestial coordinates and time
# + Friday (Matt in Englad): Come to class, open time for catching up on image calibration or color image
#
# Matt will be in England for the Astropy Coordination Meeting.

# %% [markdown]
# ### When else will Matt be gone this semester?
#
# + Fri, Nov 6 @ AAVSO meeting
# + Mon, Nov 9 @ AAVSO meeting

# %% [markdown]
# ## Color image step 1 today: pick the images
#
# Today we will take the next steps towards making our color image
#
# - Delete ones you don't want to include
# - Align (also called reprojecting) the images
#
# 1. Go to your jupyter folder → `calibrated-nights` → `color-images-2026` → folder for your object *with your name on it*
# 2. Open the launcher (open folder view, click the blue "+")
# 3. Open an "Image viewers" notebook
# 4. Look through your images and delete any ones you do not want to include -- delete them by right-clicking in the file browser view and selecting delete.

# %% [markdown]
# ## Color image step 2 today: reproject (align) the images
#
# 1. Open a "Reproject images" notebook
# 2. Follow the instructions in the notebook

# %% [markdown]
# ## The unexpected thing....
