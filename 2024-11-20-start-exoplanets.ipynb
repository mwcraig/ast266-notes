# %% [markdown]
# # 2024-11-20 Exoplanets
#
# Pick ONE of the planet candidate options below:
#
# 1. TIC 129108133, observed 09-21 local
# 2. ~~TIC 154576989, observed 09-24 local~~
# 3. TIC 129108133, observed 09-26 local
#     1. gp filter
#     2. rp filter
# 1. TIC 404488903, observed 09-28 local (event NOT expected)
# 2. TIC 233795794, observed 09-30
# 3. TIC 452743735, observed 10-03
# 4. TIC 115453244, observed 10-03
#     1. gp filter
#     2. rp filter
# 1. TIC 250839071, observed 10-16
# 2. TIC 365447203, observed 10-16
# 3. TIC 370981403, observed 10-17
#     1. gp filter
#     2. rp filter
# 1. TIC 283165117, observed 10-19
# 3. TIC 404516402, observed 10-20

# %% [markdown]
# ## Next steps
#
# + Run the "Generate TESS target list" notebook
# + Open [ExoFOP-TESS](https://exofop.ipac.caltech.edu/tess/)

# %%
from astropy.time import Time
from astropy import units as u
