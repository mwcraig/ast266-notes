# %% [markdown]
# # 2024-11-20 Exoplanets
#
# Pick ONE of the planet candidate options below:
#
# 1. TIC 129108133, observed 09-21 local
# 2. ~~TIC 154576989, observed 09-24 local~~
# 3. TIC 129108133, observed 09-26 local
#     1. gp filter
#     2. rp filter
# 1. TIC 404488903, observed 09-28 local (event NOT expected)
# 2. TIC 233795794, observed 09-30
# 3. TIC 452743735, observed 10-03
# 4. TIC 115453244, observed 10-03
#     1. gp filter
#     2. rp filter
# 1. TIC 250839071, observed 10-16
# 2. TIC 365447203, observed 10-16
# 3. TIC 370981403, observed 10-17
#     1. gp filter
#     2. rp filter
# 1. TIC 283105117, observed 10-19
# 2. TIC 404516402, observed 10-20

# %% [markdown]
# ## Next steps
#
# + Run the "Generate TESS target list" notebook
# + Open [ExoFOP-TESS](https://exofop.ipac.caltech.edu/tess/)

# %%
from astropy.time import Time
from astropy import units as u

# %%
epoch = Time(2459847.572572, format='jd', scale='tdb')
epoch.iso
# Out:
# '2022-09-25 01:44:30.221'

# %%
period = 3.7330471 * u.day

# %%
next_transit = epoch + period
next_transit.iso
# Out:
# '2022-09-28 19:20:05.490'

# %% [markdown]
# ## Time predictions, the hard way

# %% [markdown]
# ### A transit
#
# First transit is at 2022-09-25 01:44:30.221, period is 3.73

# %% [markdown]
# 2022-09-28 1:44 + 16.8 hours
# 2022-09-28 17:44 + 0.8 hours
# 2022-09-28 17:44 + 0:48
# 2022-09-28 18:32

# %% [markdown]
# ### My lunch
#
# My lunch today 2024-11-20 at 19:00 UTC
#
# I always have 1.9 days between lunches
#
# When will my next lunch be?
#
# 2024-11-21 19:00 + 0.9 days
# 2024-11-21 19:00 + 21.6 hours
# 2024-11-21 (19:00 + 21) + 0.6hour
# 2024-11-21 (40:00) + 0.6 hour
# 2024-11-21 (1 day + 16:00) + 0.6 hour
# 2024-11-22 16:00 + 0.6 hour
# 2024-11-22 16:36

# %% [markdown]
# ## Time predictions, the easier way
#
# + Start with a Julian date
# + Add the period to get next event
# + Convert from Julian date to ISO or ISOT

# %%
## print the epoch
epoch
# Out:
# <Time object: scale='tdb' format='jd' value=2459847.572572>

# %%
period = 3.7330471 * u.day

2459847.572572 + 3.7330471
# Out:
# 2459851.3056190996

# %%
(epoch + period).iso
# Out:
# '2022-09-28 19:20:05.490'
