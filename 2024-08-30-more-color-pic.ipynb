# %% [markdown]
# # 2024-08-30 More color picture things

# %%
from IPython.display import Image

# %% [markdown]
# ## What will the objects you are interested in look like in our telescope?
#
# ### Note: they will not be as nice as a Hubble or JWST picture but they will be yours
#
# This website will give you an idea of how large your objects will be in our telescope. There are some settings you need to make.
#
# First, the site (both links go to the same place): [Telescope Simulator](https://telescopius.com/telescope-simulator) OR
#  [https://telescopius.com/telescope-simulator](https://telescopius.com/telescope-simulator)

# %% [markdown]
# ### Telescope settings
#
# The numbers you need to enter are in the green boxes.

# %%
Image('media/TS-telesope-settings.png')

# %% [markdown]
# ### Camera settings

# %%
Image('media/TS-camera-settings.png')

# %% [markdown]
# ## Options if your object is too big to fit in our camera
#
# + Find someone else interested in the object and team up -- each of you will work on a piece then we'll stitch them together.
# + Choose a different object.
#
# ## Options if your object is super small loooking
#
# + Crop the final image -- this works fine for the dumbell nebula, for example.
# + Choose a different object
