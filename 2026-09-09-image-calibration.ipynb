# %% [markdown]
# # 2026-09-09 Image calibration

# %% [markdown]
# ## Reminders
#
# ### 1. Every image (including dark, flat and science) has bias built into it
#
# ![Combined bias image](media/sample-bias-combined.png)
#
#
# #### 😀 Good news! Bias can be subtracted!

# %% [markdown]
# ### 2. Every image *except* bias has dark current built into it; the longer the exposure, the more dark current there is
#
# ![Combined dark aafter bias subtraction](media/sample-dark-combined-bias-sub.png)
#
# #### 😀 Good news! Dark current can be subtracted!

# %% [markdown]
# ### 3. Every science image has imperfect illumination (vignetting, dust shadows)
#
# ![V band combined flat image](media/flat-B-combined-2026-08-22.png)
#
# #### 😀 Good news! Flat images measure the strength of the shadows!

# %% [markdown]
# ## Calibration recipe
#
# 1. Subtract bias
#     1. Combine several bias images to measure the bias
# 3. Subtract dark, scaled to match exposure time
#     1. Combine several dark images to measure the dark current
# 5. Divide by flat
#     1. Combine several flat images to measure the shadows.
#     2. Scale the images so their typical value is 1.

# %% [markdown]
# + You should have created a folder calleed "sample-calibrated" inside your "jupyter" folder. That is where the calibrated images you make will end up. **It is important that this be inside your "jupyter" folder -- that is the place on the server with enough space to hold the calibrated images.**
#
# + Create a "Image calibration" notebook inside your "sample-calibrated" folder if you don't already have one.
#
# + The settings you will need are here: https://astro-research-setup.readthedocs.io/en/latest/calibration/camera-apogee-alta-cg16m/
#
# + The uncalibrated images are in "uncalibrated-nights/sample-for-reduction"
#
# + One of the questions on the next homework asks you the turn a screenshot of one of your calibrated images of NGC891.
